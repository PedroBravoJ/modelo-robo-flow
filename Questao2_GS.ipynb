# %%
# !pip install roboflow
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 kB 1.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 7.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 16.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 9.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.2/72.2 kB 9.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.8.1.78
#     Uninstalling opencv-python-headless-4.8.1.78:
#       Successfully uninstalled opencv-python-headless-4.8.1.78
# ...

# %%
from roboflow import Roboflow
from IPython.display import Image, display
rf = Roboflow(api_key='oE2Q8k0oqurzBkAB1ChH')
project = rf.workspace().project('doencas-de-pele')
model = project.version(1).model
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# Imagem para teste do modelo:
print(model.predict("/content/acne-teste-2.jpg", confidence=40, overlap=30).json())
# Out:
# {'predictions': [{'x': 142.5, 'y': 36.5, 'width': 83.0, 'height': 73.0, 'confidence': 0.648078203201294, 'class': 'acne', 'class_id': 0, 'image_path': '/content/acne-teste-2.jpg', 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': '275', 'height': '183'}}

# %%
# Imagem para teste do modelo:
model.predict("/content/acne-teste-2.jpg", confidence=40, overlap=30).save("acne-teste-processed.jpg")

# %%
display(Image(filename="/content/acne-teste-processed.jpg"))

# %%
# Imagem para teste do modelo:
print(model.predict("/content/rosacea-teste.jpg", confidence=40, overlap=30).json())
# Out:
# {'predictions': [{'x': 220.0, 'y': 120.0, 'width': 104.0, 'height': 78.0, 'confidence': 0.7046661972999573, 'class': 'rosacea', 'class_id': 2, 'image_path': '/content/rosacea-teste.jpg', 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': '318', 'height': '159'}}

# %%
# Imagem para teste do modelo:
model.predict("/content/rosacea-teste.jpg", confidence=40, overlap=30).save("rosacea-teste-processed.jpg")

# %%
display(Image(filename="/content/rosacea-teste-processed.jpg"))

# %%
# Imagem para teste do modelo:
print(model.predict("/content/melasma-teste.jpg", confidence=40, overlap=30).json())
# Out:
# {'predictions': [{'x': 115.0, 'y': 136.0, 'width': 158.0, 'height': 132.0, 'confidence': 0.8342603445053101, 'class': 'melasma', 'class_id': 1, 'image_path': '/content/melasma-teste.jpg', 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': '249', 'height': '202'}}

# %%
# Imagem para teste do modelo:
model.predict("/content/melasma-teste.jpg", confidence=40, overlap=30).save("melasma-teste-processed.jpg")

# %%
display(Image(filename="/content/melasma-teste-processed.jpg"))
